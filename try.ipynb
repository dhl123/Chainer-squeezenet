# %%
from ImgDef import *
example=ImgDef()
example.load_weights()
a=example.identify("imgnet/timg.jpg")
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-cf97e0b76f9a> in <module>()
#       1 from ImgDef import *
#       2 example=ImgDef()
# ----> 3 example.load_weights()
#       4 a=example.identify("imgnet/timg.jpg")
#       5 print(a)
#
# TypeError: load_weights() takes no arguments (1 given)

# %%
["大篮子","排球","金鱼","箱子","垃圾桶","沙发床","兔","钢笔","秒表","瓶盖","小提琴","消防车","燕雀","担架","虎斑猫","手机","火炉","杯子","菜刀","电吉他"]

# %%
serializers.load_npz('squeezenet.model', model)

# %%
# %%time
import numpy as np
from PIL import Image
img=Image.open("imgnet/timg.jpg")
img=img.resize((227,227))
img=np.asarray(img,dtype=np.float32)
img=img.transpose(2, 0, 1)
#img=np.array([img])
# Out:
# CPU times: user 20 ms, sys: 0 ns, total: 20 ms
# Wall time: 16 ms

# %%
y=model(np.array([img,img]))
np.argmax(y.data)
# Out:
# (2, 128, 55, 55)
# (2, 512, 13, 13)
# (2, 20, 15, 15)
# (2, 20, 1, 1)
# 17
